# %%
from IPython import display
import os
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random as python_random
import tensorflow as tf
import seaborn as sns
import math
from sklearn.metrics import classification_report, confusion_matrix,plot_confusion_matrix

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# Coronavirus disease (COVID-19) is an infectious disease caused by the SARS-CoV-2 virus.
#
# Most people who fall sick with COVID-19 will experience mild to moderate symptoms and recover without special treatment.
#
# However, some will become seriously ill and require medical attention.
#
# In general, respiratory specimens such as deep throat saliva, combined throat and nasal swab and nasopharyngeal specimens
#
# are the specimen types of choice for diagnosing COVID-19 infection.
#
# <h3>Objective of this kernel...</h3>
#
# The CNN image classification could also be the one of approaches to diagnose the covid19.
#
# By obtaining the xray images, it can be one of the effective alternatives to diagnose the patient who is potentially infected with covid.

# %%
# ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from PIL import ImageFilter

height, width = 224, 224
batch_size=64


def generate_data(DIR):
    datagen = ImageDataGenerator(rescale=1./255.)
    
    generator = datagen.flow_from_directory(
        DIR,
        batch_size=batch_size,
        shuffle=True,
        seed=42,
        class_mode='binary',
        target_size=(height, width),
        classes={'Normal': 0, 'Viral Pneumonia': 1,'Covid': 2}
    )
    return generator

TRAINING_DIR = '../input/covid19-image-dataset/Covid19-dataset/train'
TESTING_DIR = '../input/covid19-image-dataset/Covid19-dataset/test'

train_generator = generate_data(TRAINING_DIR)
test_generator = generate_data(TESTING_DIR)

total_image = np.concatenate([train_generator.labels,test_generator.labels])

print('\n\n',{'Normal_cases':len(np.where(total_image==0)[0]),
      'Viral_Pneumonia_cases':len(np.where(total_image==1)[0]),
             'Covid_cases':len(np.where(total_image==2)[0])})
# Out:
# Found 251 images belonging to 3 classes.
# Found 66 images belonging to 3 classes.
#
#
#  {'Normal_cases': 90, 'Viral_Pneumonia_cases': 90, 'Covid_cases': 137}

# %% [markdown]
# <h3>Images demonstration<h3>

# %%
def image_plot(generator,image_numbers):
    img_feature = generator[0][0][:image_numbers]
    img_label = generator[0][1][:image_numbers]

    plt.figure(figsize=(20, 15))
    for i in range(image_numbers):
        ax = plt.subplot(math.ceil(image_numbers/4),4, i + 1)
        plt.imshow(img_feature[i])
        plt.title("Normal" if img_label[i] == 0 else "Viral Pneumonia" if img_label[i] == 1 else "Covid")
        plt.axis("off")

image_plot(train_generator,15)

# %% [markdown]
# <h3>VGG16 implementation</h3>
#
# The reason that I added 2 more dense layers is to identify more clearly from the grayscale image.
#
# The dropout layers are regularization for preventing overfitting.

# %%
from tensorflow.keras.layers.experimental import preprocessing

tf.keras.backend.clear_session()
input_shape = (height, width, 3)
base_model = tf.keras.applications.vgg16.VGG16(
    weights='imagenet', 
    include_top=False,
    input_shape=input_shape
)
base_model.trainable = False

model_vgg16 = tf.keras.Sequential()
model_vgg16.add(base_model)
model_vgg16.add(tf.keras.layers.GlobalAveragePooling2D())

model_vgg16.add(tf.keras.layers.Flatten())
model_vgg16.add(tf.keras.layers.Dense(256, activation='relu'))
model_vgg16.add(tf.keras.layers.Dropout(0.5))
model_vgg16.add(tf.keras.layers.Dense(256, activation='relu'))
model_vgg16.add(tf.keras.layers.Dropout(0.5))

model_vgg16.add(tf.keras.layers.Dense(3, activation='softmax'))

model_vgg16.compile(loss='SparseCategoricalCrossentropy', 
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=['acc'])
model_vgg16.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 14,912,579
# Trainable params: 197,891
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('model/vgg16_best.h5', monitor='acc', verbose=1, mode='max',save_best_only=True)
early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min",restore_best_weights=True, patience=5)

callbacks_list = [checkpoint,early]

history = model_vgg16.fit(
        train_generator,
        validation_data = test_generator,
        #steps_per_epoch=10,
        epochs=50, 
        shuffle=False, 
        verbose=True,
        callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 4/4 [==============================] - 30s 5s/step - loss: 1.2078 - acc: 0.3865 - val_loss: 1.0450 - val_acc: 0.3939
#
# Epoch 00001: acc improved from -inf to 0.38645, saving model to model/vgg16_best.h5
# Epoch 2/50
# 4/4 [==============================] - 12s 3s/step - loss: 1.1162 - acc: 0.4343 - val_loss: 0.9682 - val_acc: 0.3939
#
# Epoch 00002: acc improved from 0.38645 to 0.43426, saving model to model/vgg16_best.h5
# Epoch 3/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.9845 - acc: 0.5219 - val_loss: 0.8984 - val_acc: 0.6515
#
# Epoch 00003: acc improved from 0.43426 to 0.52191, saving model to model/vgg16_best.h5
# Epoch 4/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.9071 - acc: 0.5339 - val_loss: 0.8213 - val_acc: 0.7424
#
# Epoch 00004: acc improved from 0.52191 to 0.53386, saving model to model/vgg16_best.h5
# Epoch 5/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.8382 - acc: 0.6375 - val_loss: 0.7375 - val_acc: 0.7879
#
# Epoch 00005: acc improved from 0.53386 to 0.63745, saving model to model/vgg16_best.h5
# Epoch 6/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.7277 - acc: 0.6813 - val_loss: 0.6660 - val_acc: 0.7879
#
# Epoch 00006: acc improved from 0.63745 to 0.68127, saving model to model/vgg16_best.h5
# Epoch 7/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.7157 - acc: 0.7211 - val_loss: 0.6007 - val_acc: 0.8333
#
# Epoch 00007: acc improved from 0.68127 to 0.72112, saving model to model/vgg16_best.h5
# Epoch 8/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.6089 - acc: 0.7888 - val_loss: 0.5350 - val_acc: 0.8788
#
# Epoch 00008: acc improved from 0.72112 to 0.78884, saving model to model/vgg16_best.h5
# Epoch 9/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.6040 - acc: 0.7371 - val_loss: 0.4908 - val_acc: 0.8939
#
# Epoch 00009: acc did not improve from 0.78884
# Epoch 10/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.5321 - acc: 0.7729 - val_loss: 0.4433 - val_acc: 0.8939
#
# Epoch 00010: acc did not improve from 0.78884
# Epoch 11/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.5270 - acc: 0.7888 - val_loss: 0.4093 - val_acc: 0.8939
#
# Epoch 00011: acc did not improve from 0.78884
# Epoch 12/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.4845 - acc: 0.8167 - val_loss: 0.3795 - val_acc: 0.9091
#
# Epoch 00012: acc improved from 0.78884 to 0.81673, saving model to model/vgg16_best.h5
# Epoch 13/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.4748 - acc: 0.8127 - val_loss: 0.3893 - val_acc: 0.8182
#
# Epoch 00013: acc did not improve from 0.81673
# Epoch 14/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.4475 - acc: 0.8367 - val_loss: 0.3467 - val_acc: 0.9091
#
# Epoch 00014: acc improved from 0.81673 to 0.83665, saving model to model/vgg16_best.h5
# Epoch 15/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3885 - acc: 0.8645 - val_loss: 0.3228 - val_acc: 0.9242
#
# Epoch 00015: acc improved from 0.83665 to 0.86454, saving model to model/vgg16_best.h5
# Epoch 16/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.3526 - acc: 0.8964 - val_loss: 0.3335 - val_acc: 0.8485
#
# Epoch 00016: acc improved from 0.86454 to 0.89641, saving model to model/vgg16_best.h5
# Epoch 17/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3304 - acc: 0.9044 - val_loss: 0.2879 - val_acc: 0.8939
#
# Epoch 00017: acc improved from 0.89641 to 0.90438, saving model to model/vgg16_best.h5
# Epoch 18/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3009 - acc: 0.9004 - val_loss: 0.2760 - val_acc: 0.9242
#
# Epoch 00018: acc did not improve from 0.90438
# Epoch 19/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3167 - acc: 0.9084 - val_loss: 0.2923 - val_acc: 0.8485
#
# Epoch 00019: acc improved from 0.90438 to 0.90837, saving model to model/vgg16_best.h5
# Epoch 20/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2950 - acc: 0.8924 - val_loss: 0.2772 - val_acc: 0.8788
#
# Epoch 00020: acc did not improve from 0.90837
# Epoch 21/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2678 - acc: 0.9163 - val_loss: 0.2642 - val_acc: 0.9242
#
# Epoch 00021: acc improved from 0.90837 to 0.91633, saving model to model/vgg16_best.h5
# Epoch 22/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2687 - acc: 0.9004 - val_loss: 0.2463 - val_acc: 0.9242
#
# Epoch 00022: acc did not improve from 0.91633
# Epoch 23/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2496 - acc: 0.9243 - val_loss: 0.2356 - val_acc: 0.9242
#
# Epoch 00023: acc improved from 0.91633 to 0.92430, saving model to model/vgg16_best.h5
# Epoch 24/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2227 - acc: 0.9243 - val_loss: 0.2348 - val_acc: 0.9091
#
# Epoch 00024: acc did not improve from 0.92430
# Epoch 25/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2317 - acc: 0.9124 - val_loss: 0.2296 - val_acc: 0.9091
#
# Epoch 00025: acc did not improve from 0.92430
# Epoch 26/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2313 - acc: 0.9163 - val_loss: 0.2279 - val_acc: 0.9091
#
# Epoch 00026: acc did not improve from 0.92430
# Epoch 27/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2134 - acc: 0.9163 - val_loss: 0.2472 - val_acc: 0.8788
#
# Epoch 00027: acc did not improve from 0.92430
# Epoch 28/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1993 - acc: 0.9363 - val_loss: 0.2066 - val_acc: 0.9545
#
# Epoch 00028: acc improved from 0.92430 to 0.93625, saving model to model/vgg16_best.h5
# Epoch 29/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1669 - acc: 0.9482 - val_loss: 0.1999 - val_acc: 0.9091
#
# Epoch 00029: acc improved from 0.93625 to 0.94821, saving model to model/vgg16_best.h5
# Epoch 30/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.2079 - acc: 0.9323 - val_loss: 0.2130 - val_acc: 0.8939
#
# Epoch 00030: acc did not improve from 0.94821
# Epoch 31/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1727 - acc: 0.9323 - val_loss: 0.2005 - val_acc: 0.9242
#
# Epoch 00031: acc did not improve from 0.94821
# Epoch 32/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1478 - acc: 0.9522 - val_loss: 0.1762 - val_acc: 0.9545
#
# Epoch 00032: acc improved from 0.94821 to 0.95219, saving model to model/vgg16_best.h5
# Epoch 33/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1755 - acc: 0.9402 - val_loss: 0.1934 - val_acc: 0.9091
#
# Epoch 00033: acc did not improve from 0.95219
# Epoch 34/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1446 - acc: 0.9522 - val_loss: 0.2195 - val_acc: 0.8939
#
# Epoch 00034: acc did not improve from 0.95219
# Epoch 35/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1255 - acc: 0.9641 - val_loss: 0.1631 - val_acc: 0.9545
#
# Epoch 00035: acc improved from 0.95219 to 0.96414, saving model to model/vgg16_best.h5
# Epoch 36/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1866 - acc: 0.9402 - val_loss: 0.1792 - val_acc: 0.9091
#
# Epoch 00036: acc did not improve from 0.96414
# Epoch 37/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1612 - acc: 0.9363 - val_loss: 0.2397 - val_acc: 0.8788
#
# Epoch 00037: acc did not improve from 0.96414
# Epoch 38/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1593 - acc: 0.9402 - val_loss: 0.1875 - val_acc: 0.9242
#
# Epoch 00038: acc did not improve from 0.96414
# Epoch 39/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1457 - acc: 0.9482 - val_loss: 0.1739 - val_acc: 0.9394
#
# Epoch 00039: acc did not improve from 0.96414
# Epoch 40/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1260 - acc: 0.9562 - val_loss: 0.1800 - val_acc: 0.9242
#
# Epoch 00040: acc did not improve from 0.96414

# %%
# plot learning curve
def plot_learning_curve(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))

    plt.plot(epochs, acc, label='training acc')
    plt.plot(epochs, val_acc, label='validation acc')
    plt.legend();
    plt.figure();

    plt.plot(epochs, loss, label='training loss')
    plt.plot(epochs, val_loss, label='validation loss')
    plt.legend();

plot_learning_curve(history)

# %%
train_result = model_vgg16.evaluate(train_generator)
test_result = model_vgg16.evaluate(test_generator)

no_augmented_df = pd.DataFrame(zip(train_result,test_result),columns=['Train','Val'],index=['Loss','Acc'])
no_augmented_df
# Out:
# 4/4 [==============================] - 10s 2s/step - loss: 0.0995 - acc: 0.9681
# 2/2 [==============================] - 1s 10ms/step - loss: 0.1631 - acc: 0.9545
#          Train       Val
# Loss  0.099488  0.163103
# Acc   0.968127  0.954545

# %%
ytest = np.array([])
xtest = []

for i in range(math.ceil(len(test_generator.classes)/batch_size)):
    xtest.append(test_generator[i][0]) 
    ytest= np.concatenate((ytest,test_generator[i][-1])) 
    
xtest = np.concatenate((xtest),axis=0)

ypred_prob =model_vgg16.predict(xtest)
ypred = np.argmax(ypred_prob,axis=1)

plt.figure(figsize=(6, 6))
hm = sns.heatmap(confusion_matrix(ytest,ypred), annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False,
            xticklabels=['Normal','Viral Penumonia','Covid'],yticklabels=['Normal','Viral Penumonia','Covid'])  
hm.set(xlabel='Predicted_labels')
hm.set(ylabel='True_labels')
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.95      0.93        20
#          1.0       0.95      0.90      0.92        20
#          2.0       1.00      1.00      1.00        26
#
#     accuracy                           0.95        66
#    macro avg       0.95      0.95      0.95        66
# weighted avg       0.96      0.95      0.95        66

# %% [markdown]
# <h3>Show the wrong classified image</h3>

# %%
#Extract wrong classification index
wrong_pred = np.where(ypred!=ytest)[0]

plt.figure(figsize=(20, 15))
for i,n in enumerate(wrong_pred):
    ax = plt.subplot(math.ceil(len(wrong_pred)/4),4, i + 1)
    plt.imshow(xtest[n])
    plt.title("Normal" if ypred[n] == 0 else "Viral Pneumonia" if ypred[n] == 1 else "Covid",color='r')
    plt.axis("off")

# %% [markdown]
# <h3>Adding image augmentation</h3>

# %%
def generate_data_augmented(DIR):
    datagen = ImageDataGenerator(
        rescale=1./255.,
        zoom_range=0.1,
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True
    )
    generator = datagen.flow_from_directory(
        TRAINING_DIR,
        batch_size=batch_size,
        seed=42,
        class_mode='binary',
        target_size=(height, width),
        classes={'Normal': 0, 'Viral Pneumonia': 1,'Covid': 2}
    )
    return generator

aug_train_generator = generate_data_augmented(TRAINING_DIR)

image_plot(aug_train_generator,15)
# Out:
# Found 251 images belonging to 3 classes.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('model/vgg16_best.h5', monitor='acc', verbose=1, mode='max',save_best_only=True)
early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min",restore_best_weights=True, patience=10)

callbacks_list = [checkpoint,early]

history = model_vgg16.fit(
        aug_train_generator,
        validation_data = test_generator,
        #steps_per_epoch=10,
        epochs=60, 
        shuffle=False, 
        verbose=True,
        callbacks=callbacks_list)
# Out:
# Epoch 1/60
# 4/4 [==============================] - 16s 4s/step - loss: 0.2464 - acc: 0.9124 - val_loss: 0.1908 - val_acc: 0.9242
#
# Epoch 00001: acc improved from -inf to 0.91235, saving model to model/vgg16_best.h5
# Epoch 2/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.2936 - acc: 0.8606 - val_loss: 0.1590 - val_acc: 0.9394
#
# Epoch 00002: acc did not improve from 0.91235
# Epoch 3/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.2839 - acc: 0.8725 - val_loss: 0.1627 - val_acc: 0.9394
#
# Epoch 00003: acc did not improve from 0.91235
# Epoch 4/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.2654 - acc: 0.9044 - val_loss: 0.2238 - val_acc: 0.9091
#
# Epoch 00004: acc did not improve from 0.91235
# Epoch 5/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.2912 - acc: 0.9044 - val_loss: 0.1649 - val_acc: 0.9545
#
# Epoch 00005: acc did not improve from 0.91235
# Epoch 6/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.2515 - acc: 0.9163 - val_loss: 0.1634 - val_acc: 0.9545
#
# Epoch 00006: acc improved from 0.91235 to 0.91633, saving model to model/vgg16_best.h5
# Epoch 7/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.2272 - acc: 0.9124 - val_loss: 0.1829 - val_acc: 0.9394
#
# Epoch 00007: acc did not improve from 0.91633
# Epoch 8/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.2356 - acc: 0.9163 - val_loss: 0.1717 - val_acc: 0.9394
#
# Epoch 00008: acc did not improve from 0.91633
# Epoch 9/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.2006 - acc: 0.9402 - val_loss: 0.1453 - val_acc: 0.9394
#
# Epoch 00009: acc improved from 0.91633 to 0.94024, saving model to model/vgg16_best.h5
# Epoch 10/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.2510 - acc: 0.9004 - val_loss: 0.1708 - val_acc: 0.9242
#
# Epoch 00010: acc did not improve from 0.94024
# Epoch 11/60
# 4/4 [==============================] - 13s 4s/step - loss: 0.2038 - acc: 0.9442 - val_loss: 0.1598 - val_acc: 0.9242
#
# Epoch 00011: acc improved from 0.94024 to 0.94422, saving model to model/vgg16_best.h5
# Epoch 12/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.2601 - acc: 0.9044 - val_loss: 0.1452 - val_acc: 0.9697
#
# Epoch 00012: acc did not improve from 0.94422
# Epoch 13/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.2502 - acc: 0.9044 - val_loss: 0.2032 - val_acc: 0.9091
#
# Epoch 00013: acc did not improve from 0.94422
# Epoch 14/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1982 - acc: 0.9163 - val_loss: 0.1563 - val_acc: 0.9697
#
# Epoch 00014: acc did not improve from 0.94422
# Epoch 15/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.2121 - acc: 0.9363 - val_loss: 0.1551 - val_acc: 0.9545
#
# Epoch 00015: acc did not improve from 0.94422
# Epoch 16/60
# 4/4 [==============================] - 13s 4s/step - loss: 0.2035 - acc: 0.9402 - val_loss: 0.1906 - val_acc: 0.9091
#
# Epoch 00016: acc did not improve from 0.94422
# Epoch 17/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1938 - acc: 0.9323 - val_loss: 0.1546 - val_acc: 0.9242
#
# Epoch 00017: acc did not improve from 0.94422
# Epoch 18/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.2013 - acc: 0.9243 - val_loss: 0.1387 - val_acc: 0.9697
#
# Epoch 00018: acc did not improve from 0.94422
# Epoch 19/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.1596 - acc: 0.9602 - val_loss: 0.2042 - val_acc: 0.8939
#
# Epoch 00019: acc improved from 0.94422 to 0.96016, saving model to model/vgg16_best.h5
# Epoch 20/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.1734 - acc: 0.9402 - val_loss: 0.1334 - val_acc: 0.9697
#
# Epoch 00020: acc did not improve from 0.96016
# Epoch 21/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.1942 - acc: 0.9163 - val_loss: 0.1302 - val_acc: 0.9697
#
# Epoch 00021: acc did not improve from 0.96016
# Epoch 22/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1715 - acc: 0.9482 - val_loss: 0.1378 - val_acc: 0.9697
#
# Epoch 00022: acc did not improve from 0.96016
# Epoch 23/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1641 - acc: 0.9402 - val_loss: 0.1431 - val_acc: 0.9697
#
# Epoch 00023: acc did not improve from 0.96016
# Epoch 24/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.1479 - acc: 0.9522 - val_loss: 0.1409 - val_acc: 0.9545
#
# Epoch 00024: acc did not improve from 0.96016
# Epoch 25/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.1752 - acc: 0.9402 - val_loss: 0.1334 - val_acc: 0.9697
#
# Epoch 00025: acc did not improve from 0.96016
# Epoch 26/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.1520 - acc: 0.9482 - val_loss: 0.1277 - val_acc: 0.9697
#
# Epoch 00026: acc did not improve from 0.96016
# Epoch 27/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.1415 - acc: 0.9482 - val_loss: 0.1319 - val_acc: 0.9697
#
# Epoch 00027: acc did not improve from 0.96016
# Epoch 28/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1511 - acc: 0.9402 - val_loss: 0.1294 - val_acc: 0.9697
#
# Epoch 00028: acc did not improve from 0.96016
# Epoch 29/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.1732 - acc: 0.9522 - val_loss: 0.1222 - val_acc: 0.9697
#
# Epoch 00029: acc did not improve from 0.96016
# Epoch 30/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.1707 - acc: 0.9283 - val_loss: 0.1375 - val_acc: 0.9394
#
# Epoch 00030: acc did not improve from 0.96016
# Epoch 31/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1373 - acc: 0.9482 - val_loss: 0.1402 - val_acc: 0.9394
#
# Epoch 00031: acc did not improve from 0.96016
# Epoch 32/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.1157 - acc: 0.9562 - val_loss: 0.1419 - val_acc: 0.9394
#
# Epoch 00032: acc did not improve from 0.96016
# Epoch 33/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1330 - acc: 0.9602 - val_loss: 0.1216 - val_acc: 0.9848
#
# Epoch 00033: acc did not improve from 0.96016
# Epoch 34/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.1227 - acc: 0.9562 - val_loss: 0.1311 - val_acc: 0.9697
#
# Epoch 00034: acc did not improve from 0.96016
# Epoch 35/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.0951 - acc: 0.9681 - val_loss: 0.1378 - val_acc: 0.9394
#
# Epoch 00035: acc improved from 0.96016 to 0.96813, saving model to model/vgg16_best.h5
# Epoch 36/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.1538 - acc: 0.9482 - val_loss: 0.1293 - val_acc: 0.9697
#
# Epoch 00036: acc did not improve from 0.96813
# Epoch 37/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.0938 - acc: 0.9602 - val_loss: 0.1084 - val_acc: 0.9848
#
# Epoch 00037: acc did not improve from 0.96813
# Epoch 38/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.1420 - acc: 0.9482 - val_loss: 0.1173 - val_acc: 0.9394
#
# Epoch 00038: acc did not improve from 0.96813
# Epoch 39/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.1672 - acc: 0.9363 - val_loss: 0.1767 - val_acc: 0.9091
#
# Epoch 00039: acc did not improve from 0.96813
# Epoch 40/60
# 4/4 [==============================] - 14s 4s/step - loss: 0.1536 - acc: 0.9442 - val_loss: 0.1168 - val_acc: 0.9848
#
# Epoch 00040: acc did not improve from 0.96813
# Epoch 41/60
# 4/4 [==============================] - 13s 3s/step - loss: 0.1460 - acc: 0.9562 - val_loss: 0.1106 - val_acc: 0.9545
#
# Epoch 00041: acc did not improve from 0.96813
# Epoch 42/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1375 - acc: 0.9402 - val_loss: 0.1260 - val_acc: 0.9697
#
# Epoch 00042: acc did not improve from 0.96813
# Epoch 43/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1292 - acc: 0.9442 - val_loss: 0.1183 - val_acc: 0.9848
#
# Epoch 00043: acc did not improve from 0.96813
# Epoch 44/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1406 - acc: 0.9522 - val_loss: 0.1177 - val_acc: 0.9394
#
# Epoch 00044: acc did not improve from 0.96813
# Epoch 45/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1007 - acc: 0.9721 - val_loss: 0.1185 - val_acc: 0.9848
#
# Epoch 00045: acc improved from 0.96813 to 0.97211, saving model to model/vgg16_best.h5
# Epoch 46/60
# 4/4 [==============================] - 14s 3s/step - loss: 0.1253 - acc: 0.9482 - val_loss: 0.1213 - val_acc: 0.9848
#
# Epoch 00046: acc did not improve from 0.97211
# Epoch 47/60
# 4/4 [==============================] - 13s 4s/step - loss: 0.1486 - acc: 0.9522 - val_loss: 0.1118 - val_acc: 0.9848
#
# Epoch 00047: acc did not improve from 0.97211

# %%
train_result = model_vgg16.evaluate(train_generator)
test_result = model_vgg16.evaluate(test_generator)

augmented_df = pd.DataFrame(zip(train_result,test_result),columns=['Train','Val'],index=['Loss','Acc'])
augmented_df
# Out:
# 4/4 [==============================] - 10s 2s/step - loss: 0.0608 - acc: 0.9801
# 2/2 [==============================] - 2s 10ms/step - loss: 0.1084 - acc: 0.9848
#          Train       Val
# Loss  0.060764  0.108382
# Acc   0.980080  0.984848

# %% [markdown]
# <h3>Final model evaluation</h3>

# %% [markdown]
# For training dataset

# %%
ytrain = np.array([])
xtrain = []

for i in range(math.ceil(len(train_generator.classes)/batch_size)):
    xtrain.append(train_generator[i][0]) 
    ytrain= np.concatenate((ytrain,train_generator[i][-1])) 
    
xtrain = np.concatenate((xtrain),axis=0)

ypred_prob =model_vgg16.predict(xtrain)
ypred = np.argmax(ypred_prob,axis=1)

plt.figure(figsize=(6, 6))
hm = sns.heatmap(confusion_matrix(ytrain,ypred), annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False,
            xticklabels=['Normal','Viral Penumonia','Covid'],yticklabels=['Normal','Viral Penumonia','Covid'])  
hm.set(xlabel='Predicted_labels')
hm.set(ylabel='True_labels')
print(classification_report(ytrain,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97        70
#          1.0       0.99      0.94      0.96        70
#          2.0       1.00      1.00      1.00       111
#
#     accuracy                           0.98       251
#    macro avg       0.98      0.98      0.98       251
# weighted avg       0.98      0.98      0.98       251

# %% [markdown]
# For testing dataset

# %%
ytest = np.array([])
xtest = []

for i in range(math.ceil(len(test_generator.classes)/batch_size)):
    xtest.append(test_generator[i][0]) 
    ytest= np.concatenate((ytest,test_generator[i][-1])) 
    
xtest = np.concatenate((xtest),axis=0)

ypred_prob =model_vgg16.predict(xtest)
ypred = np.argmax(ypred_prob,axis=1)

plt.figure(figsize=(6, 6))
hm = sns.heatmap(confusion_matrix(ytest,ypred), annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False,
            xticklabels=['Normal','Viral Penumonia','Covid'],yticklabels=['Normal','Viral Penumonia','Covid'])  
hm.set(xlabel='Predicted_labels')
hm.set(ylabel='True_labels')
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.97        20
#          1.0       0.95      1.00      0.98        20
#          2.0       1.00      1.00      1.00        26
#
#     accuracy                           0.98        66
#    macro avg       0.98      0.98      0.98        66
# weighted avg       0.99      0.98      0.98        66
